# %%
import tensorflow as tf
import input_data

mnist = input_data.read_data_sets("data",one_hot=True)

batch_size = 50

n_batch = mnist.train.num_examples // batch_size

x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])
keep_prob=tf.placeholder(tf.float32)
lr = tf.Variable(0.001,dtype=tf.float32)

#create simple NeuroNet
W1 = tf.Variable(tf.truncated_normal([784,500],stddev=0.1))
b1 = tf.Variable(tf.zeros([500])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)

W2 = tf.Variable(tf.truncated_normal([500,200],stddev=0.1))
b2 = tf.Variable(tf.zeros([200])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([200,10],stddev=0.1))
b3 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.softmax(tf.matmul(L2_drop,W3)+b3)

#cost function
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
#train with gradient descent
train_step = tf.train.AdamOptimizer(lr).minimize(loss)

#initialize variables
init = tf.global_variables_initializer()

#find accuracy of trained model
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))   #convert a list of booleans into a single boolean value
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(31):
        sess.run(tf.assign(lr, 0.001 * (0.95 ** epoch)))
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:1.0})
        
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        
        print("Iter" + str(epoch) + ", Testing Accuracy: " + str(test_acc) + ", Learning Rate: " + str(sess.run(lr)))
# Out:
# Extracting data\train-images-idx3-ubyte.gz
# Extracting data\train-labels-idx1-ubyte.gz
# Extracting data\t10k-images-idx3-ubyte.gz
# Extracting data\t10k-labels-idx1-ubyte.gz
# Iter0, Testing Accuracy: 0.954, Learning Rate: 0.001
# Iter1, Testing Accuracy: 0.9599, Learning Rate: 0.00095
# Iter2, Testing Accuracy: 0.9688, Learning Rate: 0.0009025
# Iter3, Testing Accuracy: 0.9721, Learning Rate: 0.000857375
# Iter4, Testing Accuracy: 0.9722, Learning Rate: 0.00081450626
# Iter5, Testing Accuracy: 0.9701, Learning Rate: 0.0007737809
# Iter6, Testing Accuracy: 0.9762, Learning Rate: 0.0007350919
# Iter7, Testing Accuracy: 0.9726, Learning Rate: 0.0006983373
# Iter8, Testing Accuracy: 0.9769, Learning Rate: 0.0006634204
# Iter9, Testing Accuracy: 0.9767, Learning Rate: 0.0006302494
# Iter10, Testing Accuracy: 0.9779, Learning Rate: 0.0005987369
# Iter11, Testing Accuracy: 0.9785, Learning Rate: 0.0005688001
# Iter12, Testing Accuracy: 0.9776, Learning Rate: 0.0005403601
# Iter13, Testing Accuracy: 0.9799, Learning Rate: 0.0005133421
# Iter14, Testing Accuracy: 0.9806, Learning Rate: 0.000487675
# Iter15, Testing Accuracy: 0.9804, Learning Rate: 0.00046329122
# Iter16, Testing Accuracy: 0.9805, Learning Rate: 0.00044012666
# Iter17, Testing Accuracy: 0.9793, Learning Rate: 0.00041812033
# Iter18, Testing Accuracy: 0.9792, Learning Rate: 0.00039721432
# Iter19, Testing Accuracy: 0.9802, Learning Rate: 0.0003773536
# Iter20, Testing Accuracy: 0.98, Learning Rate: 0.00035848594
# Iter21, Testing Accuracy: 0.9801, Learning Rate: 0.00034056162
# Iter22, Testing Accuracy: 0.9802, Learning Rate: 0.00032353355
# Iter23, Testing Accuracy: 0.9822, Learning Rate: 0.00030735688
# Iter24, Testing Accuracy: 0.9815, Learning Rate: 0.000291989
# Iter25, Testing Accuracy: 0.9814, Learning Rate: 0.00027738957
# Iter26, Testing Accuracy: 0.9799, Learning Rate: 0.0002635201
# Iter27, Testing Accuracy: 0.9814, Learning Rate: 0.00025034408
# Iter28, Testing Accuracy: 0.9806, Learning Rate: 0.00023782688
# Iter29, Testing Accuracy: 0.9814, Learning Rate: 0.00022593554
# Iter30, Testing Accuracy: 0.9825, Learning Rate: 0.00021463877
